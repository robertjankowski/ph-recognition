# %% [markdown]
# # ph recognition based on the image color
#  ***
#
#  ### I downloaded ph-scale images from [link](https://www.shutterstock.com/search/ph+scale). Then I split every image to 15 small ones and I labeled it based on the ph

# %%
import cv2 # for images
import matplotlib.pyplot as plt
import pickle
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn import svm
from sklearn.externals import joblib
import os
from load_data import LoadData

pd.set_option('display.max_columns', None)

# %%
data = LoadData(44)
df = data.load_data()
df = shuffle(df)
df.shape
# Out:
# no image
# no image
# no image
# no image
# no image
# no image
# no image
# (653, 4)

# %%
y = np.array(df['label']) 
X = np.array(df.drop(['label'], axis=1))
# print(y)

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.scatter(df.label, df.blue, c=df.label)
plt.xlabel('label')
plt.ylabel('blue')
plt.title('Blue color')
plt.show()

# %%
plt.scatter(df.label, df.red, c=df.label)
plt.xlabel('label')
plt.ylabel('red')
plt.title('Red color')
plt.show()

# %%
plt.scatter(df.label, df.green, c=df.label)
plt.xlabel('label')
plt.ylabel('green')
plt.title('Green color')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df.blue, df.green, df.red, c=df.label)
ax.set_xlabel('Blue')
ax.set_ylabel('Green')
ax.set_zlabel('Red')

plt.show()
fig.savefig('plot3d_v1.png')

# %% [markdown]
# ### Plotly

# %%
import plotly
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# make color array 
colors = np.array([df.blue,df.green,df.red])
colors.shape
# Out:
# (3, 653)

# %%
ph_colors = go.Scatter3d(
    x=df.blue,
    y=df.green,
    z=df.red,
    mode='markers',
    marker =dict(size=5,color=df.label,colorscale='Viridis'),
    name ='PH-scale'
)

data = [ph_colors]
layout = go.Layout(
    margin = dict(l=0,r=0,b=0,t=0),
    scene = dict(
        xaxis = dict(title='blue'),
        yaxis = dict(title='green'),
        zaxis = dict(title='red'),)
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig,filename='ph-scale')
# Out:
# <div id="989771ed-4f80-452f-9212-0d776efa2711" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '989771ed-4f80-452f-9212-0d776efa2711',
#             [{"marker": {"color": [4.0, 11.0, 10.0, 2.0, 2.0, 7.0, 9.0, 13.0, 10.0, 9.0, 0.0, 3.0, 4.0, 6.0, 5.0, 4.0, 7.0, 3.0, 7.0, 10.0, 8.0, 6.0, 6.0, 7.0, 2.0, 7.0, 7.0, 11.0, 14.0, 5.0, 2.0, 5.0, 4.0, 7.0, 9.0, 3.0, 11.0, 11.0, 1.0, 1.0, 9.0, 1.0, 5.0, 14.0, 13.0, 10.0, 0.0, 1.0, 4.0, 1.0, 4.0, 11.0, 5.0, 0.0, 2.0, 3.0, 10.0, 7.0, 7.0, 6.0, 9.0, 11.0, 5.0, 6.0, 13.0, 3.0, 10.0, 10.0, 4.0, 0.0, 13.0, 12.0, 11.0, 6.0, 8.0, 8.0, 4.0, 12.0, 10.0, 13.0, 5.0, 8.0, 1.0, 1.0, 0.0, 3.0, 5.0, 1.0, 9.0, 7.0, 2.0, 14.0, 9.0, 14.0, 4.0, 8.0, 12.0, 7.0, 11.0, 12.0, 9.0, 2.0, 2.0, 8.0, 10.0, 4.0, 4.0, 12.0, 2.0, 2.0, 12.0, 3.0, 8.0, 11.0, 3.0, 11.0, 8.0, 0.0, 5.0, 5.0, 5.0, 0.0, 14.0, 8.0, 14.0, 14.0, 6.0, 14.0, 3.0, 13.0, 8.0, 9.0, 8.0, 8.0, 11.0, 2.0, 11.0, 14.0, 9.0, 13.0, 10.0, 3.0, 3.0, 12.0, 2.0, 3.0, 9.0, 6.0, 13.0, 14.0, 12.0, 2.0, 7.0, 13.0, 13.0, 1.0, 2.0, 8.0, 0.0, 4.0, 9.0, 9.0, 2.0
0, 14.0, 10.0, 1.0, 12.0, 0.0, 0.0, 11.0, 4.0, 2.0, 1.0, 11.0, 1.0, 7.0, 11.0, 11.0, 6.0, 4.0, 3.0, 6.0, 7.0, 10.0, 8.0, 0.0, 14.0, 6.0, 3.0, 6.0, 3.0, 14.0, 13.0, 2.0, 2.0, 5.0, 8.0, 14.0, 11.0, 12.0, 1.0, 1.0, 7.0, 14.0, 11.0, 1.0, 10.0, 5.0, 7.0, 5.0, 0.0, 0.0, 13.0, 10.0, 4.0, 9.0, 4.0, 13.0, 13.0, 14.0, 0.0, 8.0, 14.0, 12.0, 9.0, 14.0, 11.0, 0.0, 2.0, 1.0, 10.0, 12.0, 1.0, 6.0, 3.0, 3.0, 10.0, 0.0, 11.0, 8.0, 11.0, 2.0, 3.0, 7.0, 1.0, 3.0, 10.0, 5.0, 11.0, 0.0, 0.0, 14.0, 6.0, 12.0, 9.0, 9.0, 10.0, 3.0, 8.0, 11.0, 5.0, 11.0, 5.0, 12.0, 3.0, 10.0, 10.0, 4.0, 3.0, 5.0, 5.0, 5.0, 2.0, 8.0, 6.0, 2.0, 6.0, 12.0, 6.0, 6.0, 1.0, 14.0, 12.0, 4.0, 4.0, 14.0, 6.0, 11.0, 6.0, 2.0, 9.0, 13.0, 1.0, 13.0, 7.0, 10.0, 9.0, 5.0, 3.0, 11.0, 3.0, 6.0, 8.0, 1.0, 10.0, 8.0, 10.0, 3.0, 9.0, 10.0, 6.0], "colorscale": "Viridis", "size": 5}, "mode": "markers", "name": "PH-scale", "x": [50.0, 150.0, 209.0, 0.0, 30.0, 0.0, 185.0, 201.0, 156.0, 182.0, 16.0, 36.0, 0.0, 73.0, 55.0, 19.0, 102.0, 1.0, 0.0, 202.0, 92.0, 62.0, 67.0, 34.0, 26.0, 67.0, 73.0, 207.0, 154.0, 65.0, 17.0, 22.0, 0.0, 73.0, 182.0, 0.0, 166.0, 203.0, 36.0, 27.0, 182.0, 13.0, 65.0, 131.0, 240.0, 70.0, 35.0, 0.0, 0.0, 40.0, 50.0, 165.0, 6.0, 24.0, 19.0, 28.0, 157.0, 67.0, 73.0, 0.0, 182.0, 203.0, 0.0, 72.0, 159.0, ...

# %% [markdown]
# # test and train data

# %%
SIZE = X.shape[0]
TRAIN_SIZE = int(SIZE*0.9)
train_x = X[:TRAIN_SIZE]
train_y = y[:TRAIN_SIZE]
test_x = X[TRAIN_SIZE:]
test_y = y[TRAIN_SIZE:]
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((587, 3), (66, 3), (587,), (66,))

# %% [markdown]
# # Testing machine learning algorithms
#
# ***

# %% [markdown]
# #### GradientBoostingRegressor

# %%
from sklearn import tree
from sklearn.ensemble import GradientBoostingRegressor
# clf = GradientBoostingRegressor()
# clf.fit(train_x, train_y)

# %% [markdown]
# #### RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
clf = RandomForestRegressor()
clf.fit(train_x, train_y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# #### GradientBoostingRegressor with tuning

# %%
clf = GradientBoostingRegressor(loss='lad', learning_rate=0.2,
                               max_depth=8,)
clf.fit(train_x, train_y)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.2, loss='lad', max_depth=8, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %% [markdown]
# #### GradientBoostingRegressor choosing best score

# %%
from sklearn.model_selection import RandomizedSearchCV
GBR = GradientBoostingRegressor()
GBR.fit(train_x,train_y)
gb_param_grid = {
    'loss': ['ls', 'lad', 'huber', 'quantile'],
    'learning_rate':[0.1, 0.05, 0.01],
    'max_depth': [4, 8],
    'min_samples_leaf': [1,2,5],
    
}
gsGBR = RandomizedSearchCV(GBR,param_distributions=gb_param_grid,cv=5,verbose=1)
gsGBR.fit(train_x,train_y)
GBR_best = gsGBR.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   19.1s finished

# %%
gsGBR.best_params_, gsGBR.best_score_
# Out:
# ({'min_samples_leaf': 1, 'max_depth': 4, 'loss': 'ls', 'learning_rate': 0.05},
#  0.9465714181593967)

# %%
from sklearn.metrics import r2_score
# testing 
def test(clf):
    accuracy = 0
    for i in range(len(test_x)):
        y_predict = clf.predict([test_x[i]])
        print('Predict {:.2f}, labels {}'.format(y_predict[0],test_y[i]))
        # add some margin
        if(abs(y_predict[0] - test_y[i]) <= 0.3):
            accuracy += 1
    accuracy = float(accuracy/len(test_x))
    print(accuracy)
    # return the mean accuracy on the given test data and labels
    r2 = r2_score(test_y, clf.predict(test_x))
    print(r2)
    return r2
# overfitting !

# %%
r2 = test(GBR_best)
# Out:
# Predict 2.92, labels 3
# Predict 9.91, labels 10
# Predict 5.42, labels 5
# Predict 10.89, labels 11
# Predict 0.14, labels 0
# Predict 1.52, labels 0
# Predict 13.77, labels 14
# Predict 3.51, labels 6
# Predict 12.26, labels 12
# Predict 8.90, labels 9
# Predict 8.90, labels 9
# Predict 10.04, labels 10
# Predict 2.94, labels 3
# Predict 7.86, labels 8
# Predict 11.96, labels 11
# Predict 6.11, labels 5
# Predict 11.09, labels 11
# Predict 6.70, labels 5
# Predict 11.88, labels 12
# Predict 1.57, labels 3
# Predict 6.74, labels 10
# Predict 9.85, labels 10
# Predict 4.03, labels 4
# Predict 4.06, labels 3
# Predict 5.31, labels 5
# Predict 5.50, labels 5
# Predict 3.78, labels 5
# Predict 2.20, labels 2
# Predict 7.96, labels 8
# Predict 6.42, labels 6
# Predict 1.81, labels 2
# Predict 6.75, labels 6
# Predict 12.37, labels 12
# Predict 5.82, labels 6
# Predict 6.42, labels 6
# Predict 1.19, labels 1
# Predict 13.77, labels 14
# Predict 11.97, labels 12
# Predict 4.34, labels 4
# Predict 4.21, labels 4
# Predict 13.31, labels 14
# Predict 5.33, labels 6
# Predict 11.97, labels 11
# Predict 6.03, labels 6
# Predict 2.41, labels 2
# Predict 8.90, labels 9
# Predict 13.44, labels 13
# Predict 1.25, labels 1
# Predict 13.18, labels 13
# Predict 6.57, labels 7
# Predict 9.85, labels 10
# Predict 11.61, labels 9
# Predict 5.58, labels 5
# Predict 2.61, labels 3
# Predict 11.09, labels 11
# Predict 3.05, labels 3
# Predict 4.06, labels 6
# Predict 8.00, labels 8
# Predict 1.35, labels 1
# Predict 10.41, labels 10
# Predict 7.97, labels 8
# Predict 10.31, labels 10
# Predict 2.94, labels 3
# Predict 8.90, labels 9
# Predict 10.16, labels 10
# Predict 7.11, labels 6
# 0.5303030303030303
# 0.9513857095447107

# %%
def static_var(varname, value):
    def decorate(func):
        setattr(func, varname, value)
        return func
    return decorate

# %%
# pickle save model
@static_var('numer',0)
def save_model(model, name):
    save_model.number += 1
    model_pickle = open('saved_models//37_datasets.pickle','wb')
    pickle.dump(model, model_pickle)
    model_pickle.close()

# %%
save_model.number = 0

# %%
save_model(GBR_best, 'GBR_best+20')

# %% [markdown]
# ## adding more datasets works, need to update old gui

# %%
GBR_best.predict(np.vstack([67,170,43]).T)
# Out:
# array([6.99970354])
